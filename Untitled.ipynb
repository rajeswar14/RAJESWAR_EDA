# %%
import pandas as pd #data frame operations
import numpy as np # math operations
import matplotlib.pyplot as plt # diagrams/plots
import seaborn as sns #diagrams/plots

# %%
path=r"C:\Users\RAJESH\OneDrive\Data science\data files\Visadataset.csv"
visa_df=pd.read_csv(path)
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
visa_df[['education_of_employee']]
# Out:
#       education_of_employee
# 0               High School
# 1                  Master's
# 2                Bachelor's
# 3                Bachelor's
# 4                  Master's
# ...                     ...
# 25475            Bachelor's
# 25476           High School
# 25477              Master's
# 25478              Master's
# 25479            Bachelor's
#
# [25480 rows x 1 columns]

# %%
visa_df['education_of_employee'].unique()
# Out:
# array(['High School', "Master's", "Bachelor's", 'Doctorate'], dtype=object)

# %%
unique_labels=visa_df['continent'].unique()
for i in unique_labels:
    con=visa_df['continent']==i
    print(i,":",len(visa_df[con]))

# %%
r=visa_df['education_of_employee'].unique()
count=[]
for i in r:
    eom=visa_df['education_of_employee']==i
    count.append(len(visa_df[eom]))
ed=pd.DataFrame
# Out:
# [3420, 9634, 10234, 2192]

# %%
continent_vc=visa_df['continent'].value_counts() # series
l1=continent_vc.keys()
l2=continent_vc.values
continent_vc_df=pd.DataFrame(zip(l1,l2),
                             columns=['continent','count'])

print(continent_vc_df)

# %%
employee_ed=visa_df['education_of_employee'].value_counts()
l1=employee_ed.keys()
l2=employee_ed.values
employee_ed_df=pd.DataFrame(zip(l1,l2),
                           columns=['education_of_employee','count'])
employee_ed_df
# Out:
#   education_of_employee  count
# 0            Bachelor's  10234
# 1              Master's   9634
# 2           High School   3420
# 3             Doctorate   2192

# %%
employee_ed_df
# Out:
#   education_of_employee  count
# 0            Bachelor's  10234
# 1              Master's   9634
# 2           High School   3420
# 3             Doctorate   2192

# %%
plt.figure(figsize=(10,6)) # to incease the plot size
plt.bar('continent',
        'count',
        data=continent_vc_df)
plt.xlabel("continent") # x-axis name
plt.ylabel('count') # y-axis name
plt.title("Bar chart") # title of the chart
plt.savefig('continent_bar.jpg')
plt.show()

# %%
plt.figure(figsize=(10,6)) # to incease the plot size
plt.bar('continent',
        'count',
        data=continent_vc_df)
plt.xlabel("continent") # x-axis name
plt.ylabel('count') # y-axis name
plt.title("Bar chart") # title of the chart
plt.savefig('continent_bar.jpg')
plt.show()

# %%
plt.figure(figsize=(10,6))
# l=['Asia', 'Oceania', 'North America', 'South America', 'Africa',
#        'Europe']
l=visa_df['continent'].value_counts().keys() # order provide automatically
sns.countplot(data=visa_df,
              x='continent',
             order=l)
plt.xlabel("continent") # x-axis name
plt.ylabel('count') # y-axis name
plt.title("Bar chart") # title of the chart
plt.savefig('continent_bar.jpg')
plt.show()

# %%
plt.figure(figsize=(10,6))
e=visa_df["education_of_employee"].value_counts().keys()
sns.countplot(data=visa_df,
             x='education_of_employee',order=e)

plt.title('bar chart')
plt.savefig('employee education.jpg')
plt.show()

# %%
plt.figure(figsize=(10,6))
e=visa_df["education_of_employee"].value_counts().keys()
sns.countplot(data=visa_df,
             x='education_of_employee',order=e)
plt.title('bar chart')
plt.savefig('employee education.jpg')
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.bar('education_of_employee','count',
       data=employee_ed_df)
plt.xlabel('continent') 
# plt.xlabel('education_of_employee')
# plt.ylabel('count')
# plt.title('bar chart')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[62], line 4
#       1 plt.figure(figsize=(10,6))
#       2 plt.bar('education_of_employee','count',
#       3        data=employee_ed_df)
# ----> 4 plt.xlabel('continent')
#
# TypeError: 'str' object is not callable
