# %% [markdown]
# # import packages

# %%
import pandas as pd #data frame operations
import numpy as np # math operations
import matplotlib.pyplot as plt # diagrams/plots
import seaborn as sns #diagrams/plots

# %%
path=r"C:\Users\RAJESH\OneDrive\Data science\data files\Visadataset.csv"
df=pd.read_csv(path)
df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %% [markdown]
# # top 5 rows

# %%
# by default 5 rows

# %%
df.head()
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 0  EZYV01      Asia           High School                  N
# 1  EZYV02      Asia              Master's                  Y
# 2  EZYV03      Asia            Bachelor's                  N
# 3  EZYV04      Asia            Bachelor's                  N
# 4  EZYV05    Africa              Master's                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
# 2                     Y            44444         2008                 West
# 3                     N               98         1897                 West
# 4                     N             1082         2005                South
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 0         592.2029         Hour                  Y      Denied
# ...

# %%
df.head(6)
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 0  EZYV01      Asia           High School                  N
# 1  EZYV02      Asia              Master's                  Y
# 2  EZYV03      Asia            Bachelor's                  N
# 3  EZYV04      Asia            Bachelor's                  N
# 4  EZYV05    Africa              Master's                  Y
# 5  EZYV06      Asia              Master's                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
# 2                     Y            44444         2008                 West
# 3                     N               98         1897                 West
# 4                     N             1082         2005                South
# 5                     N             2339         2012                South
#
# ...

# %% [markdown]
# $tail$
# # last 5 rows

# %%
df.tail()
#by default 5 last rows
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 25475                     Y             2601         2008
# 25476                     N             3274         2006
# 25477                     N             1121         1910
# 25478                     Y             1918         1887
# 25479                     N             3195         1960
#
#       region_of_employment  prevailing_wage unit_of_wage full_time_position  \
# 25475                South         77092.57         Year                  Y
# ...

# %% [markdown]
# $shape$
#
# **number of rows and number of columns**

# %%
df.shape #it gives no of rows and columns
# Out:
# (25480, 12)

# %%
print("the number of rows: ",df.shape[0])
print("the number of columns: ",df.shape[1])
# Out:
# the number of rows:  25480
# the number of columns:  12

# %% [markdown]
# $size$
#
# **how many indices are there provide by size**

# %%
df.size
# Out:
# 305760

# %%
25480*12
# Out:
# 305760

# %% [markdown]
# $columns$

# %%
df.columns # all the columns values
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'no_of_employees', 'yr_of_estab',
#        'region_of_employment', 'prevailing_wage', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
type(df.columns)
# Out:
# pandas.core.indexes.base.Index

# %% [markdown]
# $data$ $types$

# %%
df.dtypes
# object means categorical
# other than object is numerical(int or float)
# Out:
# case_id                   object
# continent                 object
# education_of_employee     object
# has_job_experience        object
# requires_job_training     object
# no_of_employees            int64
# yr_of_estab                int64
# region_of_employment      object
# prevailing_wage          float64
# unit_of_wage              object
# full_time_position        object
# case_status               object
# dtype: object

# %%
type(df.dtypes)
# Out:
# pandas.core.series.Series

# %% [markdown]
# $task-1$

# %% [markdown]
# **extract numerical columns and categorical columns by using dtypes output**

# %%
#convert above one into dictionary
#key and values
#if for list
dict(df.dtypes)
# Out:
# {'case_id': dtype('O'),
#  'continent': dtype('O'),
#  'education_of_employee': dtype('O'),
#  'has_job_experience': dtype('O'),
#  'requires_job_training': dtype('O'),
#  'no_of_employees': dtype('int64'),
#  'yr_of_estab': dtype('int64'),
#  'region_of_employment': dtype('O'),
#  'prevailing_wage': dtype('float64'),
#  'unit_of_wage': dtype('O'),
#  'full_time_position': dtype('O'),
#  'case_status': dtype('O')}

# %%
numerical=[]
categorical=[]
if df.dtypes==dtype(0):
    numerical.append(df.dtypes)
else:
    categorical.append(df.dtypes)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[38], line 3
#       1 numerical=[]
#       2 categorical=[]
# ----> 3 if df.dtypes==dtype(0):
#       4     numerical.append(df.dtypes)
#       5 else:
#
# NameError: name 'dtype' is not defined

# %%
d1=dict(df.dtypes)
for i in d1:
    print(i,d1[i])
    if d1[i]=='object':
        print(i)
cat=[i for i in d1 if d1[i]=='object'] #<output> <for loop> <if cond>
num=[i for i in d1 if d1[i]!='object']
# Out:
# case_id object
# case_id
# continent object
# continent
# education_of_employee object
# education_of_employee
# has_job_experience object
# has_job_experience
# requires_job_training object
# requires_job_training
# no_of_employees int64
# yr_of_estab int64
# region_of_employment object
# region_of_employment
# prevailing_wage float64
# unit_of_wage object
# unit_of_wage
# full_time_position object
# full_time_position
# case_status object
# case_status

# %%
cat
# Out:
# ['case_id',
#  'continent',
#  'education_of_employee',
#  'has_job_experience',
#  'requires_job_training',
#  'region_of_employment',
#  'unit_of_wage',
#  'full_time_position',
#  'case_status']

# %%
num
# Out:
# ['no_of_employees', 'yr_of_estab', 'prevailing_wage']

# %%
# categorical data available
df.select_dtypes(include='object').columns
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'region_of_employment', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
# numerical columns
df.select_dtypes(exclude='object').columns
# Out:
# Index(['no_of_employees', 'yr_of_estab', 'prevailing_wage'], dtype='object')

# %%
#df has 12 columns
#df.select_dtypes(include="object") has 9 columns
#df.select_dtypes(exclude="object") has 3 columns

# %% [markdown]
# $isnull$

# %% [markdown]
# **it check if data has any missing values are null are present**

# %%
df.isnull()
#true means yes there is null value
# false means no there is no null value
# Out:
#        case_id  continent  education_of_employee  has_job_experience  \
# 0        False      False                  False               False
# 1        False      False                  False               False
# 2        False      False                  False               False
# 3        False      False                  False               False
# 4        False      False                  False               False
# ...        ...        ...                    ...                 ...
# 25475    False      False                  False               False
# 25476    False      False                  False               False
# 25477    False      False                  False               False
# 25478    False      False                  False               False
# 25479    False      False                  False               False
#
#        requires_job_training  no_of_employees  yr_of_estab  \
# 0                      False            False        False
# ...

# %%
# when you open excel sheet the data has empty
# which means that data is missed
# when u read that using pandas
# at that particular positions it display as NULL #because if we type null in empty  spaces it means some value is present

# %%
df.isnull().sum() # if it is zero means there is no missing values
# Out:
# case_id                  0
# continent                0
# education_of_employee    0
# has_job_experience       0
# requires_job_training    0
# no_of_employees          0
# yr_of_estab              0
# region_of_employment     0
# prevailing_wage          0
# unit_of_wage             0
# full_time_position       0
# case_status              0
# dtype: int64

# %% [markdown]
# **to drop duplicate values()**

# %%
df.drop_duplicates()
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %% [markdown]
# $info$

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25480 entries, 0 to 25479
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   case_id                25480 non-null  object
#  1   continent              25480 non-null  object
#  2   education_of_employee  25480 non-null  object
#  3   has_job_experience     25480 non-null  object
#  4   requires_job_training  25480 non-null  object
#  5   no_of_employees        25480 non-null  int64
#  6   yr_of_estab            25480 non-null  int64
#  7   region_of_employment   25480 non-null  object
#  8   prevailing_wage        25480 non-null  float64
#  9   unit_of_wage           25480 non-null  object
#  10  full_time_position     25480 non-null  object
#  11  case_status            25480 non-null  object
# dtypes: float64(1), int64(2), object(9)
# memory usage: 2.3+ MB

# %% [markdown]
# - head
# - tail
# - shape
# - size
# - columns
# - dtypes
# - isnull
# - isnull.sum
# - drop duplicates
# - info
# - len

# %%
len(df)
# Out:
# 25480

# %% [markdown]
# **bound method**
# - you need to keep brackets
#
# **not callable**
# - you need to remove brackets
#
# **attribute error**
# - the method is not available
# - check the spelling mistakes

# %%
# we want read some samples of data
# we know head will gives top 5
# we know tail will give last 5
# if you want specific rows and columns

# %% [markdown]
# $take$-$loc$-$iloc$

# %%
df.take([2,3,4])
#2.,3,4 are columns or rows
#axis =1 reference as columns 
# axis = 0 reference as rows
# by default axis=0,rows
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 2  EZYV03      Asia            Bachelor's                  N
# 3  EZYV04      Asia            Bachelor's                  N
# 4  EZYV05    Africa              Master's                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 2                     Y            44444         2008                 West
# 3                     N               98         1897                 West
# 4                     N             1082         2005                South
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 2        122996.86         Year                  Y      Denied
# 3         83434.03         Year                  Y      Denied
# 4        149907.39         Year                  Y   Certified

# %%
df.take([2,5,7],axis=1)
# Out:
#       education_of_employee  no_of_employees region_of_employment
# 0               High School            14513                 West
# 1                  Master's             2412            Northeast
# 2                Bachelor's            44444                 West
# 3                Bachelor's               98                 West
# 4                  Master's             1082                South
# ...                     ...              ...                  ...
# 25475            Bachelor's             2601                South
# 25476           High School             3274            Northeast
# 25477              Master's             1121                South
# 25478              Master's             1918                 West
# 25479            Bachelor's             3195              Midwest
#
# [25480 rows x 3 columns]

# %%
df.take([100,200,300])
# Out:
#      case_id continent education_of_employee has_job_experience  \
# 100  EZYV101      Asia              Master's                  Y
# 200  EZYV201      Asia             Doctorate                  Y
# 300  EZYV301      Asia              Master's                  Y
#
#     requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 100                     N             2227         2007            Northeast
# 200                     N             3282         1979                 West
# 300                     N             3268         2012              Midwest
#
#      prevailing_wage unit_of_wage full_time_position case_status
# 100         28243.79         Year                  Y   Certified
# 200         74441.11         Year                  Y   Certified
# 300        101371.21         Year                  Y   Certified

# %%
# i want 100 ,200,300 from 4 8 11 columns
df.take([100,200,300]).take([4,8,11],axis=1)
# Out:
#     requires_job_training  prevailing_wage case_status
# 100                     N         28243.79   Certified
# 200                     N         74441.11   Certified
# 300                     N        101371.21   Certified

# %% [markdown]
# **take does not take both rows and columns at a time**

# %%
# df.iloc[<rows>,<columns>]
# df.iloc[<start:end>,<start:end>]
# rows=[]
# cols=[]
# df.iloc[rows,columns]

# %%
df.iloc[5:10] # all the columns
# Out:
#   case_id      continent education_of_employee has_job_experience  \
# 5  EZYV06           Asia              Master's                  Y
# 6  EZYV07           Asia            Bachelor's                  N
# 7  EZYV08  North America            Bachelor's                  Y
# 8  EZYV09           Asia            Bachelor's                  N
# 9  EZYV10         Europe             Doctorate                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 5                     N             2339         2012                South
# 6                     N             4985         1994                South
# 7                     N             3035         1924                 West
# 8                     N             4810         2012              Midwest
# 9                     N             2251         1995                South
#
#    prevailing_wage unit_of_wage full_time_position case_status
# ...

# %%
df.iloc[5:10,2:5]
# Out:
#   education_of_employee has_job_experience requires_job_training
# 5              Master's                  Y                     N
# 6            Bachelor's                  N                     N
# 7            Bachelor's                  Y                     N
# 8            Bachelor's                  N                     N
# 9             Doctorate                  Y                     N

# %%
df.iloc[:,2:5]
# Out:
#       education_of_employee has_job_experience requires_job_training
# 0               High School                  N                     N
# 1                  Master's                  Y                     N
# 2                Bachelor's                  N                     Y
# 3                Bachelor's                  N                     N
# 4                  Master's                  Y                     N
# ...                     ...                ...                   ...
# 25475            Bachelor's                  Y                     Y
# 25476           High School                  Y                     N
# 25477              Master's                  Y                     N
# 25478              Master's                  Y                     Y
# 25479            Bachelor's                  Y                     N
#
# [25480 rows x 3 columns]

# %%
df.iloc[5:10] # all the columns
df.iloc[5:10,2:5] # specific rows and columns
df.iloc[:,2:5] # all the rows
df.iloc[[100,200,300]] # specific rows
df.iloc[[100,200,300],[4,8,11]] #specific columns

# %%
df.iloc[[100,200,300],[4,8,11]]
# Out:
#     requires_job_training  prevailing_wage case_status
# 100                     N         28243.79   Certified
# 200                     N         74441.11   Certified
# 300                     N        101371.21   Certified

# %%
df.iloc[[100,200,300],[4,8,11]]

# %%
#only prevailing_wage
df.iloc[[100,200,300],[8]] # with [8] data frame
df.iloc[[100,200,300],8] # with 8 gives the values
# Out:
# 100     28243.79
# 200     74441.11
# 300    101371.21
# Name: prevailing_wage, dtype: float64

# %%
df.iloc[[100,200,300],[8]] # with [8] data frame
# Out:
#      prevailing_wage
# 100         28243.79
# 200         74441.11
# 300        101371.21

# %%
df.loc[[100,200,300],["full_time_position"]] # we can provide the name of column if we know
# Out:
#     full_time_position
# 100                  Y
# 200                  Y
# 300                  Y

# %%
df.loc[[100,200,300],[10]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[76], line 1
# ----> 1 df.loc[[100,200,300],[10]]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1097, in _LocationIndexer.__getitem__(self, key)
#    1095     if self._is_scalar_access(key):
#    1096         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1097     return self._getitem_tuple(key)
#    1098 else:
#    1099     # we by definition only have the 0th axis
#    1100     axis = self.axis or 0
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1287, in _LocIndexer._getitem_tuple(self, tup)
#    1285 # ugly hack for GH #836
#    1286 if self._multi_take_opportunity(tup):
# -> 1287     return self._multi_take(tup)
#    1289 return self._getitem_tuple_same_dim(tup)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1238, in _LocIndexer._multi_take(self, tup)
# ...
